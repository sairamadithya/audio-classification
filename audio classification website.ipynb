# %%
# !pip install librosa
# Out:
# Collecting librosa
#   Downloading librosa-0.10.0.post2-py3-none-any.whl (253 kB)
#      -------------------------------------- 253.0/253.0 kB 3.9 MB/s eta 0:00:00
# Collecting soundfile>=0.12.1
#   Downloading soundfile-0.12.1-py2.py3-none-win_amd64.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.51.0 in c:\users\sairam\anaconda3\lib\site-packages (from librosa) (0.53.1)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\sairam\anaconda3\lib\site-packages (from librosa) (1.6.2)
# Collecting soxr>=0.3.2
#   Downloading soxr-0.3.5-cp38-cp38-win_amd64.whl (184 kB)
#      ------------------------------------- 184.4/184.4 kB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: msgpack>=1.0 in c:\users\sairam\anaconda3\lib\site-packages (from librosa) (1.0.2)
# Collecting audioread>=2.1.9
#   Downloading audioread-3.0.0.tar.gz (377 kB)
#      -------------------------------------- 377.0/377.0 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting typing-extensions>=4.1.1
#   Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\sairam\anaconda3\lib\site-packages (from librosa) (5.0.6)
# Requirement already satisfied: joblib>=0.14 in c:\users\sairam\anaconda3\lib\site-packages (from librosa) (1.0.1)
# Collecting pooch<1.7,>=1.0
#   Downloading pooch-1.6.0-py3-none-any.whl (56 kB)
#      ---------------------------------------- 56.3/56.3 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\sairam\anaconda3\lib\site-packages (from librosa) (1.1.2)
# Collecting lazy-loader>=0.1
#   Downloading lazy_loader-0.2-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\sairam\anaconda3\lib\site-packages (from librosa) (1.22.4)
# Requirement already satisfied: setuptools in c:\users\sairam\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (52.0.0.post20210125)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in c:\users\sairam\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (0.36.0)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\sairam\anaconda3\lib\site-packages (from pooch<1.7,>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in c:\users\sairam\anaconda3\lib\site-packages (from pooch<1.7,>=1.0->librosa) (2.25.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\sairam\anaconda3\lib\site-packages (from pooch<1.7,>=1.0->librosa) (20.9)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sairam\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->librosa) (2.1.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\sairam\anaconda3\lib\site-packages (from soundfile>=0.12.1->librosa) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\sairam\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.20)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\sairam\anaconda3\lib\site-packages (from packaging>=20.0->pooch<1.7,>=1.0->librosa) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\sairam\anaconda3\lib\site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\sairam\anaconda3\lib\site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sairam\anaconda3\lib\site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sairam\anaconda3\lib\site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (2022.12.7)
# Building wheels for collected packages: audioread
#   Building wheel for audioread (setup.py): started
#   Building wheel for audioread (setup.py): finished with status 'done'
#   Created wheel for audioread: filename=audioread-3.0.0-py3-none-any.whl size=23694 sha256=6ed93c682506e3a439fb53329f910dc29db55ad9bad8d891b9463544f9becced
#   Stored in directory: c:\users\sairam\appdata\local\pip\cache\wheels\0a\ed\be\49df2538fca496690a024a4374455584d65c2afd6fc3d6e9c7
# Successfully built audioread
# Installing collected packages: typing-extensions, soxr, lazy-loader, audioread, soundfile, pooch, librosa
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.7.4.3
#     Uninstalling typing-extensions-3.7.4.3:
#       Successfully uninstalled typing-extensions-3.7.4.3
# Successfully installed audioread-3.0.0 lazy-loader-0.2 librosa-0.10.0.post2 pooch-1.6.0 soundfile-0.12.1 soxr-0.3.5 typing-extensions-4.5.0
#
# [notice] A new release of pip available: 22.1.2 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\sairam\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\sairam\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\sairam\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -pencv-python (c:\users\sairam\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\sairam\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\sairam\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\sairam\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\sairam\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\sairam\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\sairam\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\sairam\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\sairam\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\sairam\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\sairam\anaconda3\lib\site-packages)

# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\sairam\anaconda3\lib\site-packages (0.88.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sairam\anaconda3\lib\site-packages (from streamlit) (8.2.0)
# Requirement already satisfied: tzlocal in c:\users\sairam\anaconda3\lib\site-packages (from streamlit) (3.0)
# Requirement already satisfied: blinker in c:\users\sairam\anaconda3\lib\site-packages (from streamlit) (1.4)
# Requirement already satisfied: astor in c:\users\sairam\anaconda3\lib\site-packages (from streamlit) (0.8.1)
# Requirement already satisfied: altair>=3.2.0 in c:\users\sairam\anaconda3\lib\site-packages (from streamlit) (4.1.0)
# Requirement already satisfied: packaging in c:\users\sairam\anaconda3\lib\site-packages (from streamlit) (20.9)
# Requirement already satisfied: attrs in c:\users\sairam\anaconda3\lib\site-packages (from streamlit) (20.3.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in c:\users\sairam\anaconda3\lib\site-packages (from streamlit) (0.7.0)
# Requirement already satisfied: base58 in c:\users\sairam\anaconda3\lib\site-packages (from streamlit) (2.1.0)
# Requirement already satisfied: pyarrow in c:\users\sairam\anaconda3\lib\site-packages (from streamlit) (5.0.0)
# Requirement already satisfied: pandas>=0.21.0 in c:\users\sairam\anaconda3\lib\site-packages (from streamlit) (1.2.4)
# Requirement already satisfied: gitpython!=3.1.19 in c:\users\sairam\anaconda3\lib\site-packages (from streamlit) (3.1.18)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in c:\users\sairam\anaconda3\lib\site-packages (from streamlit) (3.17.3)
# Requirement already satisfied: tornado>=5.0 in c:\users\sairam\anaconda3\lib\site-packages (from streamlit) (6.1)
# Requirement already satisfied: watchdog in c:\users\sairam\anaconda3\lib\site-packages (from streamlit) (1.0.2)
# Requirement already satisfied: python-dateutil in c:\users\sairam\anaconda3\lib\site-packages (from streamlit) (2.8.1)
# Requirement already satisfied: numpy in c:\users\sairam\anaconda3\lib\site-packages (from streamlit) (1.22.4)
# Requirement already satisfied: validators in c:\users\sairam\anaconda3\lib\site-packages (from streamlit) (0.18.2)
# Requirement already satisfied: toml in c:\users\sairam\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: requests in c:\users\sairam\anaconda3\lib\site-packages (from streamlit) (2.25.1)
# Requirement already satisfied: click<8.0,>=7.0 in c:\users\sairam\anaconda3\lib\site-packages (from streamlit) (7.1.2)
# Requirement already satisfied: cachetools>=4.0 in c:\users\sairam\anaconda3\lib\site-packages (from streamlit) (4.2.2)
# Requirement already satisfied: jinja2 in c:\users\sairam\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (2.11.3)
# Requirement already satisfied: jsonschema in c:\users\sairam\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (3.2.0)
# Requirement already satisfied: toolz in c:\users\sairam\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (0.11.1)
# Requirement already satisfied: entrypoints in c:\users\sairam\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (0.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\sairam\anaconda3\lib\site-packages (from gitpython!=3.1.19->streamlit) (4.0.7)
# Requirement already satisfied: pytz>=2017.3 in c:\users\sairam\anaconda3\lib\site-packages (from pandas>=0.21.0->streamlit) (2021.1)
# Requirement already satisfied: six>=1.9 in c:\users\sairam\anaconda3\lib\site-packages (from protobuf!=3.11,>=3.6.0->streamlit) (1.15.0)
# Requirement already satisfied: ipykernel>=5.1.2 in c:\users\sairam\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (5.3.4)
# Requirement already satisfied: traitlets>=4.3.2 in c:\users\sairam\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (5.0.5)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\sairam\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (7.6.3)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\sairam\anaconda3\lib\site-packages (from packaging->streamlit) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\sairam\anaconda3\lib\site-packages (from requests->streamlit) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\sairam\anaconda3\lib\site-packages (from requests->streamlit) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sairam\anaconda3\lib\site-packages (from requests->streamlit) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sairam\anaconda3\lib\site-packages (from requests->streamlit) (2022.12.7)
# Requirement already satisfied: backports.zoneinfo in c:\users\sairam\anaconda3\lib\site-packages (from tzlocal->streamlit) (0.2.1)
# Requirement already satisfied: tzdata in c:\users\sairam\anaconda3\lib\site-packages (from tzlocal->streamlit) (2021.1)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\sairam\anaconda3\lib\site-packages (from validators->streamlit) (5.0.6)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\sairam\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (4.0.0)
# Requirement already satisfied: ipython>=5.0.0 in c:\users\sairam\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (7.22.0)
# Requirement already satisfied: jupyter-client in c:\users\sairam\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (6.1.12)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\sairam\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\sairam\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\sairam\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\sairam\anaconda3\lib\site-packages (from jinja2->altair>=3.2.0->streamlit) (1.1.1)
# Requirement already satisfied: ipython-genutils in c:\users\sairam\anaconda3\lib\site-packages (from traitlets>=4.3.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: setuptools in c:\users\sairam\anaconda3\lib\site-packages (from jsonschema->altair>=3.2.0->streamlit) (52.0.0.post20210125)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\sairam\anaconda3\lib\site-packages (from jsonschema->altair>=3.2.0->streamlit) (0.17.3)
# Requirement already satisfied: jedi>=0.16 in c:\users\sairam\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.17.2)
# Requirement already satisfied: pygments in c:\users\sairam\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (2.8.1)
# Requirement already satisfied: backcall in c:\users\sairam\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: colorama in c:\users\sairam\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.4.4)
# Requirement already satisfied: pickleshare in c:\users\sairam\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\sairam\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (3.0.17)
# Requirement already satisfied: jupyter-core in c:\users\sairam\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.7.1)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\sairam\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.3.0)
# Requirement already satisfied: pyzmq>=13 in c:\users\sairam\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (20.0.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\sairam\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\sairam\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (227)
# Requirement already satisfied: nbconvert in c:\users\sairam\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.0.7)
# Requirement already satisfied: prometheus-client in c:\users\sairam\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.10.1)
# Requirement already satisfied: argon2-cffi in c:\users\sairam\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (20.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\sairam\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.9.4)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\sairam\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.0)
# Requirement already satisfied: wcwidth in c:\users\sairam\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.5)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\sairam\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\sairam\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.14.5)
# Requirement already satisfied: jupyterlab-pygments in c:\users\sairam\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\sairam\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\sairam\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.4.3)
# Requirement already satisfied: testpath in c:\users\sairam\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.4.4)
# Requirement already satisfied: bleach in c:\users\sairam\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.3.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\sairam\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.3)
# Requirement already satisfied: defusedxml in c:\users\sairam\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.7.1)
# Requirement already satisfied: pycparser in c:\users\sairam\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.20)
# Requirement already satisfied: nest-asyncio in c:\users\sairam\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.1)
# Requirement already satisfied: async-generator in c:\users\sairam\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.10)
# Requirement already satisfied: webencodings in c:\users\sairam\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)
#
# [notice] A new release of pip available: 22.1.2 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\sairam\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\sairam\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\sairam\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\sairam\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\sairam\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\sairam\anaconda3\lib\site-packages)

# %%
# %%writefile audio_test.py
import streamlit as st
import librosa, librosa.display
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from audio_recorder_streamlit import audio_recorder
import soundfile as sf
def load_model():
        model=tf.keras.models.load_model(r"C:\Users\sairam\Downloads\urbansound8k-2.9.h5")
        return model
with st.spinner('Model is being loaded..'):
        model=load_model()
st.title('Audio classification project')
st.write('this website can classify audio samples into 10 different categories:-')
st.write('1.air conditioner')
st.write('2. car horn')
st.write('3. children playing')
st.write('4. dog bark')
st.write('5. drilling')
st.write('6. engine idling')
st.write('7. gun shot')
st.write('8. jackhammer')
st.write('9. siren')
st.write('10. street music')
st.write('Please record or upload the audio sample')
file=st.file_uploader("Choose a file",type=[".wav",".mp3"])
if file is None:
        st.warning('Please upload a valid file!!')
else:
        st.audio(file,format="audio/wav")
        audio, sample_rate = librosa.load(file) 
        mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=128)
        mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
        mfccs_scaled_features=mfccs_scaled_features.reshape(1,-1)
        predicted_label=model.predict(mfccs_scaled_features)
        a=np.argmax(predicted_label,axis=1)
        if st.button('predict'):
            if a==0:
                out='air conditioner'
            elif a==1:
                out='car horn'
            elif a==2:
                out='children laying'
            elif a==3:
                out='dog bark'
            elif a==4:
                out='drilling'
            elif a==5:
                out='engine idling'
            elif a==6:
                out='gun shot'
            elif a==7:
                out='jackhammer'
            elif a==8:
                out='siren'
            else:
                out='street music'
            st.success('the given audio sample is predicted as:- '+str(out))
# Out:
# Overwriting audio_test.py

# %%
# !streamlit run audio_test.py
# Out:
# ^C
